# %%
import robotic as ry
import numpy as np
import random
from glob import glob
import os

# %%
def add_random_joints(color, file_path="base.g", n=np.random.randint(1, 10), size = .1):
    pixles = [[0, 0, 0]]
    base = f"""base {{}}

cube0 (base) {{ 
    shape: box, 
    size: [{size}, {size}, {size}], 
    color: {color}, 
    X: "t(0 0 0)" 
}}"""

    for i in range(1, n):
        parent = random.choice(pixles)
        new_popsition = parent.copy()

        while new_popsition in pixles:
            new_popsition[np.random.randint(0, 3)] += .1

        base += f"""
joint{i}(cube{i-1}):{{
  joint: rigid,
  pre: "T t({parent[0]} {parent[1]} {parent[2]})" 
}}

cube{i}(joint{i}):{{ 
  shape: box, 
  size: [{size}, {size}, {size}], 
  color: {color},
  position: [{new_popsition[0]}, {new_popsition[1]}, {new_popsition[2]}],
  X: "t({new_popsition[0]} {new_popsition[1]} {new_popsition[2]})" 
}}
"""
        pixles.append(new_popsition)
    with open("./data/"+str(int(np.random.rand()*1000))+".g", 'w', encoding='utf-8') as f: f.write(base)

# %%
# define this loop as much as you want 
os.makedirs("./data", exist_ok=True)

for i in range(100):
    add_random_joints(color=np.random.randint(0, 2, (3, )), size=.01)

# %%
# run this cell to visualize all the voxels generated
p = [0, 0, 0]
C = ry.Config()

for f in glob("./data/*.g"):
    r = np.random.randint(1, 10, (3,))
    C.addFile(f).setPosition(p+r)

# %%
C.view()
# Out:
# STACK9 /home/mahyar/miniconda3/envs/segman/lib/python3.12/site-packages/robotic/_robotic.so(+0x7f6c7) [0x7fd7477626c7]
# STACK8 rai::Configuration::view(bool, char const*)
# STACK7 OpenGL::update(bool, bool)
# STACK6 OpenGL::openWindow()
# STACK5 /home/mahyar/miniconda3/envs/segman/lib/python3.12/site-packages/robotic/librai.so(+0xa33e21) [0x7fd745aa7e21]
# STACK4 /home/mahyar/miniconda3/envs/segman/lib/python3.12/site-packages/robotic/librai.so(glfwInit
# STACK3 /home/mahyar/miniconda3/envs/segman/lib/python3.12/site-packages/robotic/librai.so(_glfwPlatformInit
# STACK2 /home/mahyar/miniconda3/envs/segman/lib/python3.12/site-packages/robotic/librai.so(_glfwInputError
# STACK1 GlfwSingleton::error_callback(int, char const*)
# STACK0 rai::LogToken::~LogToken()
# == ERROR:opengl.cpp:error_callback:129(-2) GLFW error 65544: X11: The DISPLAY environment variable is missing
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 C.view()
#
# RuntimeError: opengl.cpp:error_callback:129(-2) GLFW error 65544: X11: The DISPLAY environment variable is missing
